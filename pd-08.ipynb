# %% [markdown]
# # Ирисы

# %% [markdown]
# ### Один из самых часто используемых датасетов - познакомьтесь с ним поближе
#
# https://archive.ics.uci.edu/ml/datasets/iris
#
# либо из папки datasets

# %% [markdown]
# ### Шаг 1. Импортируем библиотеки.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Шаг 2. Импортируем датасет

# %%
# path = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
path = '../datasets/iris.data'

# %% [markdown]
# ### Шаг 3. Записываем его в переменную iris.

# %%
iris=pd.read_csv('/home/ambr2000/Downloads/Iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### Шаг 4. Создайте дополнительные колонки.

# %%
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class
iris[['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']]\
    = iris[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']]
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ### Шаг 5. Есть ли пропущенные значения?

# %%
iris.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Шаг 6. Зададим значение NaN для строк с 10 по 29 колонки 'petal_length'

# %%
from numpy import nan as NaN
iris.loc[9:28, 'petal_length'] = NaN

# %% [markdown]
# ### Шаг 7. Отлично, теперь заменим NaN на 1.0

# %%
iris.fillna(1.0)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  sepal_length  sepal_width  petal_length  petal_width  \
# 0       Iris-setosa           5.1          3.5           1.4          0.2
# 1       Iris-setosa           4.9          3.0           1.4          0.2
# 2       Iris-setosa           4.7          3.2           1.3          0.2
# 3       Iris-setosa           4.6          3.1           1.5          0.2
# 4       Iris-setosa           5.0          3.6           1.4          0.2
# ..              ...           ...          ...           ...          ...
# 145  Iris-virginica           6.7          3.0           5.2          2.3
# 146  Iris-virginica           6.3          2.5           5.0          1.9
# 147  Iris-virginica           6.5          3.0           5.2          2.0
# 148  Iris-virginica           6.2          3.4           5.4          2.3
# 149  Iris-virginica           5.9          3.0           5.1          1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 11 columns]

# %% [markdown]
# ### Шаг 8. Удалим колонку class

# %%
iris.drop('class',axis=1)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  sepal_length  sepal_width  petal_length  petal_width
# 0       Iris-setosa           5.1          3.5           1.4          0.2
# 1       Iris-setosa           4.9          3.0           1.4          0.2
# 2       Iris-setosa           4.7          3.2           1.3          0.2
# 3       Iris-setosa           4.6          3.1           1.5          0.2
# 4       Iris-setosa           5.0          3.6           1.4          0.2
# ..              ...           ...          ...           ...          ...
# 145  Iris-virginica           6.7          3.0           5.2          2.3
# 146  Iris-virginica           6.3          2.5           5.0          1.9
# 147  Iris-virginica           6.5          3.0           5.2          2.0
# 148  Iris-virginica           6.2          3.4           5.4          2.3
# 149  Iris-virginica           5.9          3.0           5.1          1.8
#
# [150 rows x 10 columns]

# %% [markdown]
# ### Шаг 9. Запишем NaN в первые 3 строки (во все колонки)

# %%
iris.iloc[:3,:]=NaN
iris.head()
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0  NaN            NaN           NaN            NaN           NaN          NaN
# 1  NaN            NaN           NaN            NaN           NaN          NaN
# 2  NaN            NaN           NaN            NaN           NaN          NaN
# 3  4.0            4.6           3.1            1.5           0.2  Iris-setosa
# 4  5.0            5.0           3.6            1.4           0.2  Iris-setosa
#
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           NaN          NaN           NaN          NaN          NaN
# 1           NaN          NaN           NaN          NaN          NaN
# 2           NaN          NaN           NaN          NaN          NaN
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ### Шаг 10. Удалим строки, в которых встречается NaN

# %%
iris=iris.dropna()

# %% [markdown]
# ### Шаг 11. Сбросим индекс - начнем его опять с 0.

# %%
iris.reset_index()
# Out:
#      index     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0        3    4.0            4.6           3.1            1.5           0.2
# 1        4    5.0            5.0           3.6            1.4           0.2
# 2        5    6.0            5.4           3.9            1.7           0.4
# 3        6    7.0            4.6           3.4            1.4           0.3
# 4        7    8.0            5.0           3.4            1.5           0.2
# ..     ...    ...            ...           ...            ...           ...
# 122    145  146.0            6.7           3.0            5.2           2.3
# 123    146  147.0            6.3           2.5            5.0           1.9
# 124    147  148.0            6.5           3.0            5.2           2.0
# 125    148  149.0            6.2           3.4            5.4           2.3
# 126    149  150.0            5.9           3.0            5.1           1.8
#
#             Species  sepal_length  sepal_width  petal_length  petal_width  \
# 0       Iris-setosa           4.6          3.1           1.5          0.2
# 1       Iris-setosa           5.0          3.6           1.4          0.2
# 2       Iris-setosa           5.4          3.9           1.7          0.4
# 3       Iris-setosa           4.6          3.4           1.4          0.3
# 4       Iris-setosa           5.0          3.4           1.5          0.2
# ..              ...           ...          ...           ...          ...
# 122  Iris-virginica           6.7          3.0           5.2          2.3
# 123  Iris-virginica           6.3          2.5           5.0          1.9
# 124  Iris-virginica           6.5          3.0           5.2          2.0
# 125  Iris-virginica           6.2          3.4           5.4          2.3
# 126  Iris-virginica           5.9          3.0           5.1          1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 122  Iris-virginica
# 123  Iris-virginica
# 124  Iris-virginica
# 125  Iris-virginica
# 126  Iris-virginica
#
# [127 rows x 12 columns]

# %% [markdown]
# ### Шаг 12. Бонус: Напишите свой вопрос и ответьте на него.

# %%
#сравните среднее арифметическое и моду длины лепестка

# %%
iris.mode()['petal_length'][0]
# Out:
# 1.5

# %%
iris['petal_length'].mean()
# Out:
# 4.174015748031496
